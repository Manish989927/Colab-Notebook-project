# %% [markdown]
# <a href="https://colab.research.google.com/github/Manish989927/Colab-Notebook-project/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8ecf736b-cc40-4427-83ee-3abd723a5cee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ecf736b-cc40-4427-83ee-3abd723a5cee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pylab import rcParams
import cv2 
import matplotlib.pyplot as plt

# %%
rcParams['figure.figsize'] = 5, 5

# %%
file_name = "images2.jpg"

# %%
img = cv2.imread(file_name)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
text_out = pytesseract.image_to_string(img)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-faaf832a8697> in <module>
# ----> 1 text_out = pytesseract.image_to_string(img)
#
# /usr/local/lib/python3.7/dist-packages/pytesseract/pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     425         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     426         Output.STRING: lambda: run_and_get_output(*args),
# --> 427     }[output_type]()
#     428
#     429
#
# /usr/local/lib/python3.7/dist-packages/pytesseract/pytesseract.py in <lambda>()
#     424         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 426         Output.STRING: lambda: run_and_get_output(*args),
#     427     }[output_type]()
#     428
#
# ...

# %%
extractedInformation = pytesseract.image_to_string(Image.open('/content/image.jpg'), lang='en')
print(extractedInformation)

# %%
image_path_in_colab="image2.jpg"
extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_colab))
print(extractedInformation)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-8b895e155408> in <module>
#       1 image_path_in_colab="image2.jpg"
# ----> 2 extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_colab))
#       3 print(extractedInformation)
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2841         from . import ImagePalette
#    2842
# -> 2843         im.palette = ImagePalette.ImagePalette()
#    2844         color = im.palette.getcolor(color)
#    2845     return im._new(core.fill(mode, size, color))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'image2.jpg'
